# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
#reading file
sp = pd.read_csv('athlete.csv')
sp.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball    No
# 1      Judo Men's Extra-Lightweight    No
# ...

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   271116 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
sp.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#null values
sp.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        9474
# Height    60171
# Weight    62875
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# dtype: int64

# %%
sp.shape
# Out:
# (271116, 15)

# %% [markdown]
# # Handle null values in dataset and remove unwanted symbols if any.

# %%
sp['Age']=sp['Age'].fillna(sp['Age'].mean())
sp['Height']=sp['Height'].fillna(sp['Height'].mean())
sp['Weight']=sp['Weight'].fillna(sp['Weight'].mean())
sp.head()
# Out:
#    ID                      Name Sex   Age     Height     Weight  \
# 0   1                 A Dijiang   M  24.0  180.00000  80.000000
# 1   2                  A Lamusi   M  23.0  170.00000  60.000000
# 2   3       Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3   4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4   5  Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
#
#              Team  NOC        Games  Year  Season       City          Sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball    No
# ...

# %% [markdown]
# # What is the unique count of sports, events, and different city, and the team participatedin the Olympics

# %%
#unique count
pd.value_counts(sp['Sport'])
# Out:
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: Sport, Length: 66, dtype: int64

# %%
sp['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
#unique event
pd.value_counts(sp['Event'])
# Out:
# Football Men's Football                                5733
# Ice Hockey Men's Ice Hockey                            4762
# Hockey Men's Hockey                                    3958
# Water Polo Men's Water Polo                            3358
# Basketball Men's Basketball                            3280
#                                                        ...
# Archery Men's Championnat Du Monde                        2
# Archery Men's Target Archery, 28 metres, Individual       2
# Basque Pelota Men's Two-Man Teams With Cesta              2
# Archery Men's Target Archery, 33 metres, Individual       2
# Aeronautics Mixed Aeronautics                             1
# Name: Event, Length: 765, dtype: int64

# %%
sp['Event'].unique()
# Out:
# array(["Basketball Men's Basketball", "Judo Men's Extra-Lightweight",
#        "Football Men's Football", "Tug-Of-War Men's Tug-Of-War",
#        "Speed Skating Women's 500 metres",
#        "Speed Skating Women's 1,000 metres",
#        "Cross Country Skiing Men's 10 kilometres",
#        "Cross Country Skiing Men's 50 kilometres",
#        "Cross Country Skiing Men's 10/15 kilometres Pursuit",
#        "Cross Country Skiing Men's 4 x 10 kilometres Relay",
#        "Cross Country Skiing Men's 30 kilometres",
#        "Athletics Women's 100 metres",
#        "Athletics Women's 4 x 100 metres Relay",
#        "Ice Hockey Men's Ice Hockey",
#        "Swimming Men's 400 metres Freestyle", "Badminton Men's Singles",
#        "Sailing Women's Windsurfer",
#        "Biathlon Women's 7.5 kilometres Sprint",
#        "Swimming Men's 200 metres Breaststroke",
#        "Swimming Men's 400 metres Breaststroke",
#        "Gymnastics Men's Individual All-Around",
# ...

# %%
#unique city
pd.value_counts(sp['City'])
# Out:
# London                    22426
# Athina                    15556
# Sydney                    13821
# Atlanta                   13780
# Rio de Janeiro            13688
# Beijing                   13602
# Barcelona                 12977
# Los Angeles               12423
# Seoul                     12037
# Munich                    10304
# Montreal                   8641
# Mexico City                8588
# Helsinki                   8270
# Roma                       8119
# Tokyo                      7702
# Moskva                     7191
# Paris                      7169
# Berlin                     6506
# Amsterdam                  4992
# Sochi                      4891
# Melbourne                  4829
# Vancouver                  4402
# Torino                     4382
# Stockholm                  4338
# Antwerpen                  4292
# Salt Lake City             4109
# Innsbruck                  3639
# Nagano                     3605
# Albertville                3436
# ...

# %%
sp['City'].unique()
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Calgary',
#        'Albertville', 'Lillehammer', 'Los Angeles', 'Salt Lake City',
#        'Helsinki', 'Lake Placid', 'Sydney', 'Atlanta', 'Stockholm',
#        'Sochi', 'Nagano', 'Torino', 'Beijing', 'Rio de Janeiro', 'Athina',
#        'Squaw Valley', 'Innsbruck', 'Sarajevo', 'Mexico City', 'Munich',
#        'Seoul', 'Berlin', 'Oslo', "Cortina d'Ampezzo", 'Melbourne',
#        'Roma', 'Amsterdam', 'Montreal', 'Moskva', 'Tokyo', 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'St. Louis', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %% [markdown]
# # Which city has the maximum number of players?

# %%
City = sp['City'].unique()

# %%
print(max(City))
# Out:
# Vancouver

# %%
#unique team
pd.value_counts(sp['Team'])
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Leipzig              1
# Mignon-29            1
# Femur-18             1
# Verveine-41          1
# Carabinier-5         1
# Name: Team, Length: 1184, dtype: int64

# %%
sp['Team'].unique
# Out:
# <bound method Series.unique of 0                  China
# 1                  China
# 2                Denmark
# 3         Denmark/Sweden
# 4            Netherlands
#                ...
# 271111          Poland-1
# 271112            Poland
# 271113            Poland
# 271114            Poland
# 271115            Poland
# Name: Team, Length: 271116, dtype: object>

# %% [markdown]
# # What is the total count of players from the United States, China, Netherland, Spain,France, Italy?

# %%
dataset= sp[sp['Team'].isin(["China","Spain","United States","Netherlands","France","Italy"])]

# %%
dataset.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0        China  CHN
# 1   2                  A Lamusi   M  23.0   170.0    60.0        China  CHN
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 0  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  2012 Summer  2012  Summer       London           Judo
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball    No
# 1        Judo Men's Extra-Lightweight    No
# ...

# %%
dataset['Team'].value_counts().plot(kind='bar',color='purple')
plt.title('Teams_player_count')
plt.ylabel('Total_number_of_players')
plt.xlabel('Teams');

# %% [markdown]
# # What is the average age of female and male players from the United States, China,Netherland, Spain, France, Italy

# %%
#only for the above mentioned teams
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="Sex", y="Age", data=dataset)

# %% [markdown]
# # What are the different kinds of sports in which players have participated in different cities of the United States.

# %%
data= sp[sp['Team'].isin([  "United States"])]

# %%
data.head()
# Out:
#     ID             Name Sex   Age  Height  Weight           Team  NOC  \
# 10   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 11   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 12   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 13   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 14   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 10  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 11  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 12  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 13  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 14  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                                 Event Medal
# 10           Cross Country Skiing Men's 10 kilometres    No
# ...

# %%
data.groupby('Sport')['City'].count().plot(kind='bar', color = 'red');
plt.title("Unied-states-sport")
plt.ylabel('Sport')
plt.xlabel('United States Cities');

# %% [markdown]
# # What are the names of players who have brought gold, silver and bronze medal?

# %%
medal_winner= sp[sp['Medal'].isin(["Gold","Silver","Bronze"])]

# %%
medal_winner.head()
# Out:
#     ID                      Name Sex   Age     Height     Weight  \
# 3    4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 37  15      Arvo Ossian Aaltonen   M  30.0  175.33897  70.702393
# 38  15      Arvo Ossian Aaltonen   M  30.0  175.33897  70.702393
# 40  16  Juhamatti Tapio Aaltonen   M  28.0  184.00000  85.000000
# 41  17   Paavo Johannes Aaltonen   M  28.0  175.00000  64.000000
#
#               Team  NOC        Games  Year  Season       City       Sport  \
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37         Finland  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38         Finland  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40         Finland  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41         Finland  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# ...

# %% [markdown]
# # Draw a suitable graph which depicts different events took place from 1900 to 2016.

# %%
sp_events = sp.groupby('Year').count()['Event'].reset_index()

# %%
plt.figure(figsize=[15,5])
plt.plot(sp_events['Year'],sp_events['Event'])
plt.xticks(rotation = 'vertical',size=8)
plt.title('different events-year-wise')
plt.ylabel('Event')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # What are the average height and weight of players who participated in football, Judo,basketball?

# %%
data_part= sp[sp['Sport'].isin(["Football","Judo","Basketball"])]

# %%
data_part.groupby('Height')['ID'].mean().plot(kind='bar', color = 'blue');
plt.title("Average height of player")
plt.ylabel('Height')
plt.xlabel('Player ');

# %%
data_part.groupby('Weight')['ID'].mean().plot(kind='bar', color = 'red');
plt.title("Average weight")
plt.ylabel('Weight')
plt.rcParams['figure.figsize']=(20,15)
plt.xlabel('Player');

# %% [markdown]
# # What are the different sports played in a different season?

# %%
sp_sports = sp[['Year', 'City', 'Season','Sport']].drop_duplicates()
sp_sports.head()
# Out:
#    Year       City  Season          Sport
# 0  1992  Barcelona  Summer     Basketball
# 1  2012     London  Summer           Judo
# 2  1920  Antwerpen  Summer       Football
# 3  1900      Paris  Summer     Tug-Of-War
# 4  1988    Calgary  Winter  Speed Skating

# %%
plt.figure(figsize=(9, 9))
sns.countplot(y='Sport', data=sp_sports, order=sp_sports['Sport'].value_counts().index,
              dodge=False, palette='seismic_r', hue='Season')
plt.title('Differenst sports as per events', size='x-large')
plt.legend(fontsize='x-large')
plt.show()

# %% [markdown]
# # How many sports and events were player in 1992 winter, 1994 winter 2000 summer 2002 winter

# %%
sea_sp=sp[sp['Games'].isin(["1992 Winter","1994 Winter","2000 Summer","2002 Winter"])]

# %%
sea_sp.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight           Team  \
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0    Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0    Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
#
#     NOC        Games  Year  Season         City                 Sport  \
# 6   NED  1992 Winter  1992  Winter  Albertville         Speed Skating
# 7   NED  1992 Winter  1992  Winter  Albertville         Speed Skating
# 8   NED  1994 Winter  1994  Winter  Lillehammer         Speed Skating
# 9   NED  1994 Winter  1994  Winter  Lillehammer         Speed Skating
# 10  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                        Event Medal
# ...

# %% [markdown]
# # sports

# %%
plt.figure(figsize=(9, 9))
sns.countplot(y='Sport', data=sea_sp, order=sea_sp['Sport'].value_counts().index,
              dodge=False, palette='seismic_r', hue='Games')
plt.title('Sport', size='x-large')
plt.legend(fontsize='x-large')
plt.show()

# %% [markdown]
# # events

# %%
plt.figure(figsize=(9, 9))
sns.countplot(y='Event', data=sea_sp, order=sea_sp['Event'].value_counts()[0:10].index,
              dodge=False, palette='seismic_r', hue='Games')
plt.title('Event', size='x-large')
plt.yticks(size = 10)
plt.legend(fontsize='x-large')
plt.show()

# %% [markdown]
# # What is the highest number of sports played in the year 1990, 1992, 1994, 2016?

# %%
high_sp= sp[sp['Year'].isin(['1990','1992','1994','2016'])]

# %%
high_sp.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0        China  CHN
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 0  1992 Summer  1992  Summer    Barcelona     Basketball
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball    No
# 6    Speed Skating Women's 500 metres    No
# ...

# %% [markdown]
# # Which team has brought the most number of female and male players?

# %%
plt.figure(figsize=(14,5))

sp.loc[sp['Sex']=='M'].groupby('Year')['Team'].nunique().plot(color='b',marker='o',label='Male Players')
sp.loc[sp['Sex']=='F'].groupby('Year')['Team'].nunique().plot(color='r',marker='o',label='Female Players')

plt.ylabel("Number of Team")
plt.legend(loc='upper left')
plt.title("Players count team-wise")
plt.grid(False)

# %% [markdown]
# # What are the different sports played by female players? In which sport, most numbers of female players have participated. Visualize the same

# %%
fe_sp= sp[sp['Sex'].isin(["F"])]

# %%
fe_sp.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 4    Speed Skating Women's 500 metres    No
# 5  Speed Skating Women's 1,000 metres    No
# ...

# %%
fe_sp['Sport'].value_counts().plot(kind='bar',color='green')
plt.title("Female most played")
plt.rcParams['figure.figsize']=(10,8)
plt.xlabel('Sports');

# %%
Me_sp= sp[sp['Sex'].isin(["M"])]

# %%
Me_sp.head()
# Out:
#     ID                  Name Sex   Age     Height     Weight            Team  \
# 0    1             A Dijiang   M  24.0  180.00000  80.000000           China
# 1    2              A Lamusi   M  23.0  170.00000  60.000000           China
# 2    3   Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393         Denmark
# 3    4  Edgar Lindenau Aabye   M  34.0  175.33897  70.702393  Denmark/Sweden
# 10   6       Per Knut Aaland   M  31.0  188.00000  75.000000   United States
#
#     NOC        Games  Year  Season         City                 Sport  \
# 0   CHN  1992 Summer  1992  Summer    Barcelona            Basketball
# 1   CHN  2012 Summer  2012  Summer       London                  Judo
# 2   DEN  1920 Summer  1920  Summer    Antwerpen              Football
# 3   DEN  1900 Summer  1900  Summer        Paris            Tug-Of-War
# 10  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                        Event Medal
# ...

# %%
Me_sp['Sport'].value_counts().plot(kind='bar',color='purple')
plt.title("Male most played")
plt.rcParams['figure.figsize']=(10,8)
plt.xlabel('Sports');

# %% [markdown]
# # Show line chart which tells variation in a number of players from 1990 to 2000 of India and Pakistan. (Draw separate chart for India and Pakistan)

# %%
df = sp[(sp['Year']>= 1990) & (sp['Year'] <= 2000) & (sp['Team'].isin(['India', 'Pakistan']))]

# %%
df.head()
# Out:
#       ID                             Name Sex   Age  Height  Weight      Team  \
# 233  111                     Aqarab Abbas   M  22.0   190.0    88.0  Pakistan
# 237  115                     Ghulam Abbas   M  24.0   181.0    74.0  Pakistan
# 247  123                     Sohail Abbas   M  25.0   178.0    80.0  Pakistan
# 899  512  Shiny Kurisingal Abraham-Wilson   F  27.0   167.0    53.0     India
# 900  512  Shiny Kurisingal Abraham-Wilson   F  31.0   167.0    53.0     India
#
#      NOC        Games  Year  Season       City      Sport  \
# 233  PAK  1996 Summer  1996  Summer    Atlanta  Athletics
# 237  PAK  1992 Summer  1992  Summer  Barcelona  Athletics
# 247  PAK  2000 Summer  2000  Summer     Sydney     Hockey
# 899  IND  1992 Summer  1992  Summer  Barcelona  Athletics
# 900  IND  1996 Summer  1996  Summer    Atlanta  Athletics
#
#                                       Event Medal
# 233            Athletics Men's Hammer Throw    No
# ...

# %%
India = pd.DataFrame(df[df['Team'] == 'India']['Year'].value_counts()).reset_index()
India.rename(columns={'index' : 'Year', 'Year': 'Players'}, inplace=True)

# No of players from Pakistan by years
Pakistan = pd.DataFrame(df[df['Team'] == 'Pakistan']['Year'].value_counts()).reset_index()
Pakistan.rename(columns={'index' : 'Year', 'Year': 'Players'}, inplace=True)

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title('No. of Indian players by years')
plt.plot(India['Year'], India['Players'])

plt.subplot(1,2,2)
plt.title('No. of Pakistan players by years')
plt.plot(Pakistan['Year'], Pakistan['Players'], 'g')

plt.show()

# %% [markdown]
# # Draw a pie chart to show the percentage of male and female players across the world

# %%
sp['Sex'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title('percentage-wise male and female')
plt.xlabel('gender');

# %% [markdown]
# # Which team has won the maximum number of gold, silver and bronze? Visualize the same.

# %%
df = sp[sp['Medal'] != 'None']
pd.crosstab(sp['Team'],sp['Medal']).sort_values(['Bronze','Silver','Gold'],ascending=(False,False,False)).head(1).plot.bar(title='Most medal winning team')
plt.show()

# %% [markdown]
# # Who is the tallest and shortest player?

# %%
print('The tallest person ever to participate in olympics was {} of height : {}'.format(sp[sp['Height'] == sp['Height'].max()]['Name'].unique()[0],sp['Height'].max()))
print('The Shortest person ever to participate in olympics was {} of height : {}'.format(sp[sp['Height'] == sp['Height'].min()]['Name'].unique()[0],sp['Height'].min()))
# Out:
# The tallest person ever to participate in olympics was Yao Ming of height : 226.0
# The Shortest person ever to participate in olympics was Rosario Briones of height : 127.0

# %% [markdown]
# # Draw a suitable chart which shows the performance of different cities belonging to Beijing, London, Sydney, Los Angeles.

# %%
df_city = sp[sp['City'].isin(['Beijing', 'London', 'Sydney', 'Los Angeles'])]

df_city = pd.DataFrame(pd.crosstab(df['City'], df_city['Medal']))
df_city.drop('No', 1, inplace=True)
df_city.plot.bar(title='Performance of different cities')
plt.show()
